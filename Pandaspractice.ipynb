# %% [markdown]
# <a href="https://colab.research.google.com/github/SaiGeethikaAkkineni/Python/blob/main/Pandaspractice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/india_housing_prices.csv')

# %%
df.head(2)
# Out:
#    ID        State     City      Locality      Property_Type  BHK  \
# 0   1   Tamil Nadu  Chennai   Locality_84          Apartment    1
# 1   2  Maharashtra     Pune  Locality_490  Independent House    3
#
#    Size_in_SqFt  Price_in_Lakhs  Price_per_SqFt  Year_Built  ...  \
# 0          4740          489.76            0.10      1990.0  ...
# 1          2364          195.52            0.08      2008.0  ...
#
#   Age_of_Property  Nearby_Schools  Nearby_Hospitals  \
# 0            35.0            10.0               3.0
# 1            17.0             8.0               1.0
#
#    Public_Transport_Accessibility  Parking_Space  Security  \
# 0                            High             No        No
# 1                             Low             No       Yes
#
#                                   Amenities Facing Owner_Type  \
# 0  Playground, Gym, Garden, Pool, Clubhouse   West      Owner
# 1  Playground, Clubhouse, Pool, Gym, Garden  North    Builder
#
#   Availability_Status
# ...

# %%
df.shape
# Out:
# (172365, 23)

# %%
df.tail()
# Out:
#             ID        State       City      Locality Property_Type  BHK  \
# 172360  172361    Telangana  Hyderabad   Locality_26         Villa    2
# 172361  172362    Karnataka  Bangalore   Locality_32     Apartment    3
# 172362  172363        Delhi  New Delhi  Locality_154     Apartment    2
# 172363  172364       Kerala      Kochi  Locality_219         Villa    4
# 172364  172365  Uttarakhand   Dehradun  Locality_390     Apartment    3
#
#         Size_in_SqFt  Price_in_Lakhs  Price_per_SqFt  Year_Built  ...  \
# 172360          3603          331.63            0.09      2011.0  ...
# 172361          4793           67.63            0.01      1992.0  ...
# 172362          1589          188.00            0.12      2016.0  ...
# 172363          3203          190.39            0.06      2019.0  ...
# 172364          4167          316.81            0.08         NaN  ...
#
#        Age_of_Property  Nearby_Schools  Nearby_Hospitals  \
# ...

# %%
df['State'].head()
# Out:
# 0     Tamil Nadu
# 1    Maharashtra
# 2         Punjab
# 3      Rajasthan
# 4      Rajasthan
# Name: State, dtype: object

# %%
df[['State','City','Locality']].tail()
# Out:
#               State       City      Locality
# 172360    Telangana  Hyderabad   Locality_26
# 172361    Karnataka  Bangalore   Locality_32
# 172362        Delhi  New Delhi  Locality_154
# 172363       Kerala      Kochi  Locality_219
# 172364  Uttarakhand   Dehradun  Locality_390

# %%
df[df['State'] == 'Gujarat'].head()
# Out:
#       ID    State       City      Locality      Property_Type  BHK  \
# 28    29  Gujarat  Ahmedabad   Locality_74  Independent House    5
# 66    67  Gujarat      Surat  Locality_169              Villa    1
# 73    74  Gujarat  Ahmedabad  Locality_387  Independent House    4
# 76    77  Gujarat      Surat  Locality_418  Independent House    3
# 117  118  Gujarat      Surat  Locality_111  Independent House    5
#
#      Size_in_SqFt  Price_in_Lakhs  Price_per_SqFt  Year_Built  ...  \
# 28           2088          233.29            0.11      1999.0  ...
# 66           2318          234.83            0.10      1997.0  ...
# 73            978          418.76            0.43      2001.0  ...
# 76           3757          470.63            0.13      2018.0  ...
# 117          2947          410.00            0.14      2007.0  ...
#
#     Age_of_Property  Nearby_Schools  Nearby_Hospitals  \
# 28             26.0             1.0               2.0
# ...

# %%
df[df['State'] == 'Gujarat'].shape
# Out:
# (8643, 23)

# %%
df[df['State'] == 'Tamil Nadu']['Price_in_Lakhs'].mean()
# Out:
# 255.8587744593203

# %%
df[(df['State']=='Tamil Nadu') & (df['City'] == 'Chennai')]['Price_in_Lakhs'].mean()
# Out:
# 256.0966682253917

# %%
df[(df['State']=='Tamil Nadu') | (df['State'] == 'Gujarat')]['Price_in_Lakhs'].mean()
# Out:
# 255.3561247267288

# %%
df.drop(columns=['Age_of_Property'], inplace=True)

# %%
df['Age_of_Property'] = 2025- df["Year_Built"]
df.head()
# Out:
#    ID        State      City      Locality      Property_Type  BHK  \
# 0   1   Tamil Nadu   Chennai   Locality_84          Apartment    1
# 1   2  Maharashtra      Pune  Locality_490  Independent House    3
# 2   3       Punjab  Ludhiana  Locality_167          Apartment    2
# 3   4    Rajasthan   Jodhpur  Locality_393  Independent House    2
# 4   5    Rajasthan    Jaipur  Locality_466              Villa    4
#
#    Size_in_SqFt  Price_in_Lakhs  Price_per_SqFt  Year_Built  ...  \
# 0          4740          489.76            0.10      1990.0  ...
# 1          2364          195.52            0.08      2008.0  ...
# 2          3642          183.79            0.05      1997.0  ...
# 3          2741          300.29            0.11      1991.0  ...
# 4          4823          182.90            0.04      2002.0  ...
#
#   Nearby_Schools  Nearby_Hospitals  Public_Transport_Accessibility  \
# 0           10.0               3.0                            High
# ...

# %%
df.notnull().sum()
# Out:
# ID                                172365
# State                             172365
# City                              172365
# Locality                          172365
# Property_Type                     172365
# BHK                               172365
# Size_in_SqFt                      172365
# Price_in_Lakhs                    172365
# Price_per_SqFt                    172365
# Year_Built                        172364
# Furnished_Status                  172364
# Floor_No                          172364
# Total_Floors                      172364
# Nearby_Schools                    172364
# Nearby_Hospitals                  172364
# Public_Transport_Accessibility    172364
# Parking_Space                     172364
# Security                          172364
# Amenities                         172364
# Facing                            172364
# Owner_Type                        172364
# Availability_Status               172364
# Age_of_Property                   172364
# ...

# %%
 df['State'] = df['State'].replace('Tamil Nadu',None)

# %%
df['State'].unique()
# Out:
# array([None, 'Maharashtra', 'Punjab', 'Rajasthan', 'West Bengal',
#        'Chhattisgarh', 'Delhi', 'Jharkhand', 'Telangana', 'Karnataka',
#        'Uttar Pradesh', 'Assam', 'Uttarakhand', 'Bihar', 'Gujarat',
#        'Haryana', 'Andhra Pradesh', 'Madhya Pradesh', 'Kerala', 'Odisha'],
#       dtype=object)

# %%
df['State']=df['State'].fillna('Tamil Nadu', inplace=True)
# Out:
# <ipython-input-25-08fd57296106>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['State']=df['State'].fillna('Tamil Nadu', inplace=True)

# %%
df[df['City'] == 'Chennai'][['State', 'City']].head()
# Out:
#          State     City
# 0   Tamil Nadu  Chennai
# 35  Tamil Nadu  Chennai
# 38  Tamil Nadu  Chennai
# 46  Tamil Nadu  Chennai
# 61  Tamil Nadu  Chennai

# %%
df1= df.groupby('State')

# %%
df1[['Price_in_Lakhs','Size_in_SqFt','Price_per_SqFt']].mean()
# Out:
#                 Price_in_Lakhs  Size_in_SqFt  Price_per_SqFt
# State
# Andhra Pradesh      255.099802   2741.461938        0.130546
# Assam               252.712231   2728.436068        0.131694
# Bihar               253.579767   2760.346823        0.130226
# Chhattisgarh        254.331677   2740.352824        0.131712
# Delhi               252.196162   2746.099197        0.129224
# Gujarat             254.847892   2766.926530        0.130015
# Haryana             255.745353   2762.125118        0.131164
# Jharkhand           254.739016   2750.747141        0.130158
# Karnataka           258.498609   2746.161404        0.133263
# Kerala              253.837375   2758.272366        0.130071
# Madhya Pradesh      256.478656   2760.981701        0.130584
# Maharashtra         255.083291   2735.005811        0.130948
# Odisha              253.381917   2767.647205        0.130645
# Punjab              252.287944   2752.362602        0.129074
# ...

# %%
df1.head()
# Out:
#       ID        State         City      Locality      Property_Type  BHK  \
# 0      1   Tamil Nadu      Chennai   Locality_84          Apartment    1
# 1      2  Maharashtra         Pune  Locality_490  Independent House    3
# 2      3       Punjab     Ludhiana  Locality_167          Apartment    2
# 3      4    Rajasthan      Jodhpur  Locality_393  Independent House    2
# 4      5    Rajasthan       Jaipur  Locality_466              Villa    4
# ..   ...          ...          ...           ...                ...  ...
# 144  145       Kerala        Kochi  Locality_255          Apartment    2
# 156  157       Odisha  Bhubaneswar  Locality_491  Independent House    4
# 160  161       Kerala   Trivandrum  Locality_231          Apartment    5
# 167  168       Odisha      Cuttack  Locality_305          Apartment    3
# 172  173       Odisha  Bhubaneswar  Locality_350              Villa    1
#
#      Size_in_SqFt  Price_in_Lakhs  Price_per_SqFt  Year_Built  ...  \
# ...

# %%
df.tail()
# Out:
#             ID        State       City      Locality Property_Type  BHK  \
# 172360  172361    Telangana  Hyderabad   Locality_26         Villa    2
# 172361  172362    Karnataka  Bangalore   Locality_32     Apartment    3
# 172362  172363        Delhi  New Delhi  Locality_154     Apartment    2
# 172363  172364       Kerala      Kochi  Locality_219         Villa    4
# 172364  172365  Uttarakhand   Dehradun  Locality_390     Apartment    3
#
#         Size_in_SqFt  Price_in_Lakhs  Price_per_SqFt  Year_Built  ...  \
# 172360          3603          331.63            0.09      2011.0  ...
# 172361          4793           67.63            0.01      1992.0  ...
# 172362          1589          188.00            0.12      2016.0  ...
# 172363          3203          190.39            0.06      2019.0  ...
# 172364          4167          316.81            0.08         NaN  ...
#
#        Nearby_Schools  Nearby_Hospitals  Public_Transport_Accessibility  \
# ...
