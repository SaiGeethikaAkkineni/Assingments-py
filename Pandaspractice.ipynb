# %% [markdown]
# <a href="https://colab.research.google.com/github/SaiGeethikaAkkineni/Python/blob/main/Pandaspractice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/india_housing_prices.csv')

# %%
df.head(2)
# Out:
#    ID        State     City      Locality      Property_Type  BHK  \
# 0   1   Tamil Nadu  Chennai   Locality_84          Apartment    1
# 1   2  Maharashtra     Pune  Locality_490  Independent House    3
#
#    Size_in_SqFt  Price_in_Lakhs  Price_per_SqFt  Year_Built  ...  \
# 0          4740          489.76            0.10        1990  ...
# 1          2364          195.52            0.08        2008  ...
#
#   Age_of_Property  Nearby_Schools  Nearby_Hospitals  \
# 0              35              10                 3
# 1              17               8                 1
#
#    Public_Transport_Accessibility  Parking_Space  Security  \
# 0                            High             No        No
# 1                             Low             No       Yes
#
#                                   Amenities Facing Owner_Type  \
# 0  Playground, Gym, Garden, Pool, Clubhouse   West      Owner
# 1  Playground, Clubhouse, Pool, Gym, Garden  North    Builder
#
#   Availability_Status
# 0       Ready_to_Move
# 1  Under_Construction
#
# [2 rows x 23 columns]

# %%
df.shape
# Out:
# (250000, 23)

# %%
df.tail()
# Out:
#             ID       State       City      Locality      Property_Type  BHK  \
# 249995  249996     Gujarat  Ahmedabad  Locality_187  Independent House    5
# 249996  249997  Tamil Nadu    Chennai  Locality_348          Apartment    1
# 249997  249998   Telangana   Warangal  Locality_225              Villa    4
# 249998  249999      Odisha    Cuttack  Locality_138              Villa    1
# 249999  250000     Haryana    Gurgaon  Locality_268  Independent House    3
#
#         Size_in_SqFt  Price_in_Lakhs  Price_per_SqFt  Year_Built  ...  \
# 249995          1995          274.75            0.14        1995  ...
# 249996          2293           13.40            0.01        2013  ...
# 249997          2910          236.94            0.08        2003  ...
# 249998          1149          141.66            0.12        2007  ...
# 249999          4313          199.69            0.05        1990  ...
#
#        Age_of_Property  Nearby_Schools  Nearby_Hospitals  \
# 249995              30               8                 6
# 249996              12               8                10
# 249997              22              10                 4
# 249998              18               3                 7
# 249999              35              10                 6
#
#         Public_Transport_Accessibility  Parking_Space  Security  \
# 249995                             Low             No        No
# 249996                             Low             No        No
# 249997                            High            Yes       Yes
# 249998                             Low            Yes       Yes
# 249999                          Medium             No        No
#
#                                        Amenities Facing Owner_Type  \
# 249995  Playground, Garden, Gym, Clubhouse, Pool   East     Broker
# 249996                                Playground  South     Broker
# 249997                                Playground  South    Builder
# 249998                     Playground, Gym, Pool  South      Owner
# 249999                               Gym, Garden  South      Owner
#
#        Availability_Status
# 249995  Under_Construction
# 249996       Ready_to_Move
# 249997  Under_Construction
# 249998       Ready_to_Move
# 249999  Under_Construction
#
# [5 rows x 23 columns]

# %%
df['State'].head()
# Out:
# 0     Tamil Nadu
# 1    Maharashtra
# 2         Punjab
# 3      Rajasthan
# 4      Rajasthan
# Name: State, dtype: object

# %%
df[['State','City','Locality']].tail()
# Out:
#              State       City      Locality
# 249995     Gujarat  Ahmedabad  Locality_187
# 249996  Tamil Nadu    Chennai  Locality_348
# 249997   Telangana   Warangal  Locality_225
# 249998      Odisha    Cuttack  Locality_138
# 249999     Haryana    Gurgaon  Locality_268

# %%
df[df['State'] == 'Gujarat'].head()
# Out:
#       ID    State       City      Locality      Property_Type  BHK  \
# 28    29  Gujarat  Ahmedabad   Locality_74  Independent House    5
# 66    67  Gujarat      Surat  Locality_169              Villa    1
# 73    74  Gujarat  Ahmedabad  Locality_387  Independent House    4
# 76    77  Gujarat      Surat  Locality_418  Independent House    3
# 117  118  Gujarat      Surat  Locality_111  Independent House    5
#
#      Size_in_SqFt  Price_in_Lakhs  Price_per_SqFt  Year_Built  ...  \
# 28           2088          233.29            0.11        1999  ...
# 66           2318          234.83            0.10        1997  ...
# 73            978          418.76            0.43        2001  ...
# 76           3757          470.63            0.13        2018  ...
# 117          2947          410.00            0.14        2007  ...
#
#     Age_of_Property  Nearby_Schools  Nearby_Hospitals  \
# 28               26               1                 2
# 66               28               9                 6
# 73               24               8                 2
# 76                7               6                 2
# 117              18               5                 3
#
#      Public_Transport_Accessibility  Parking_Space  Security  \
# 28                           Medium            Yes       Yes
# 66                             High            Yes       Yes
# 73                             High            Yes        No
# 76                             High            Yes       Yes
# 117                          Medium            Yes        No
#
#                                     Amenities Facing Owner_Type  \
# 28                               Pool, Garden   East      Owner
# 66                                        Gym   East      Owner
# 73   Clubhouse, Garden, Gym, Pool, Playground   East      Owner
# 76                                        Gym  South    Builder
# 117                         Garden, Gym, Pool  South     Broker
#
#     Availability_Status
# 28        Ready_to_Move
# 66   Under_Construction
# 73   Under_Construction
# 76   Under_Construction
# 117  Under_Construction
#
# [5 rows x 23 columns]

# %%
df[df['State'] == 'Gujarat'].shape
# Out:
# (12578, 23)

# %%
df[df['State'] == 'Tamil Nadu']['Price_in_Lakhs'].mean()
# Out:
# 256.66368358539864

# %%
df[(df['State']=='Tamil Nadu') & (df['City'] == 'Chennai')]['Price_in_Lakhs'].mean()
# Out:
# 256.8301718547341

# %%
df[(df['State']=='Tamil Nadu') | (df['State'] == 'Gujarat')]['Price_in_Lakhs'].mean()
# Out:
# 256.22775617883923

# %%
df.drop(columns=['Age_of_Property'], inplace=True)

# %%
df['Age_of_Property'] = 2025- df["Year_Built"]
df.head()
# Out:
#    ID        State      City      Locality      Property_Type  BHK  \
# 0   1   Tamil Nadu   Chennai   Locality_84          Apartment    1
# 1   2  Maharashtra      Pune  Locality_490  Independent House    3
# 2   3       Punjab  Ludhiana  Locality_167          Apartment    2
# 3   4    Rajasthan   Jodhpur  Locality_393  Independent House    2
# 4   5    Rajasthan    Jaipur  Locality_466              Villa    4
#
#    Size_in_SqFt  Price_in_Lakhs  Price_per_SqFt  Year_Built  ...  \
# 0          4740          489.76            0.10        1990  ...
# 1          2364          195.52            0.08        2008  ...
# 2          3642          183.79            0.05        1997  ...
# 3          2741          300.29            0.11        1991  ...
# 4          4823          182.90            0.04        2002  ...
#
#   Nearby_Schools  Nearby_Hospitals  Public_Transport_Accessibility  \
# 0             10                 3                            High
# 1              8                 1                             Low
# 2              9                 8                             Low
# 3              5                 7                            High
# 4              4                 9                             Low
#
#    Parking_Space  Security                                 Amenities Facing  \
# 0             No        No  Playground, Gym, Garden, Pool, Clubhouse   West
# 1             No       Yes  Playground, Clubhouse, Pool, Gym, Garden  North
# 2            Yes        No          Clubhouse, Pool, Playground, Gym  South
# 3            Yes       Yes  Playground, Clubhouse, Gym, Pool, Garden  North
# 4             No       Yes  Playground, Garden, Gym, Pool, Clubhouse   East
#
#   Owner_Type Availability_Status Age_of_Property
# 0      Owner       Ready_to_Move              35
# 1    Builder  Under_Construction              17
# 2     Broker       Ready_to_Move              28
# 3    Builder       Ready_to_Move              34
# 4    Builder       Ready_to_Move              23
#
# [5 rows x 23 columns]

# %%
df.notnull().sum()
# Out:
# ID                                250000
# State                             250000
# City                              250000
# Locality                          250000
# Property_Type                     250000
# BHK                               250000
# Size_in_SqFt                      250000
# Price_in_Lakhs                    250000
# Price_per_SqFt                    250000
# Year_Built                        250000
# Furnished_Status                  250000
# Floor_No                          250000
# Total_Floors                      250000
# Nearby_Schools                    250000
# Nearby_Hospitals                  250000
# Public_Transport_Accessibility    250000
# Parking_Space                     250000
# Security                          250000
# Amenities                         250000
# Facing                            250000
# Owner_Type                        250000
# Availability_Status               250000
# Age_of_Property                   250000
# dtype: int64

# %%
 df['State'] = df['State'].replace('Tamil Nadu',None)

# %%
df['State'].unique()
# Out:
# array([None, 'Maharashtra', 'Punjab', 'Rajasthan', 'West Bengal',
#        'Chhattisgarh', 'Delhi', 'Jharkhand', 'Telangana', 'Karnataka',
#        'Uttar Pradesh', 'Assam', 'Uttarakhand', 'Bihar', 'Gujarat',
#        'Haryana', 'Andhra Pradesh', 'Madhya Pradesh', 'Kerala', 'Odisha'],
#       dtype=object)

# %%
df['State'].fillna('Tamil Nadu', inplace=True)
# Out:
# <ipython-input-18-6242c5e2b191>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['State'].fillna('Tamil Nadu', inplace=True)

# %%
df[df['City'] == 'Chennai'][['State', 'City']].head()
# Out:
#          State     City
# 0   Tamil Nadu  Chennai
# 35  Tamil Nadu  Chennai
# 38  Tamil Nadu  Chennai
# 46  Tamil Nadu  Chennai
# 61  Tamil Nadu  Chennai

# %%
df1= df.groupby('State')

# %%
df1[['Price_in_Lakhs','Size_in_SqFt','Price_per_SqFt']].mean()
# Out:
#                 Price_in_Lakhs  Size_in_SqFt  Price_per_SqFt
# State
# Andhra Pradesh      255.197870   2730.944712        0.132037
# Assam               252.779235   2729.976633        0.130819
# Bihar               254.919040   2758.996200        0.130513
# Chhattisgarh        252.676337   2744.812219        0.130243
# Delhi               252.529900   2749.710883        0.129477
# Gujarat             255.790061   2753.505009        0.130995
# Haryana             254.445784   2758.606139        0.130692
# Jharkhand           253.610145   2743.451603        0.129754
# Karnataka           257.408465   2739.763039        0.132538
# Kerala              254.367332   2768.820373        0.129849
# Madhya Pradesh      255.961459   2754.604931        0.130717
# Maharashtra         254.706280   2739.820873        0.130703
# Odisha              252.838743   2757.440659        0.130322
# Punjab              252.796877   2747.479626        0.129311
# Rajasthan           254.600214   2751.366634        0.129336
# Tamil Nadu          256.663684   2761.156782        0.131367
# Telangana           255.535173   2751.071377        0.130957
# Uttar Pradesh       256.249920   2740.493844        0.131417
# Uttarakhand         254.677234   2755.936165        0.130245
# West Bengal         254.008640   2758.131437        0.130645

# %%
df1.head()
# Out:
#       ID        State         City      Locality      Property_Type  BHK  \
# 0      1   Tamil Nadu      Chennai   Locality_84          Apartment    1
# 1      2  Maharashtra         Pune  Locality_490  Independent House    3
# 2      3       Punjab     Ludhiana  Locality_167          Apartment    2
# 3      4    Rajasthan      Jodhpur  Locality_393  Independent House    2
# 4      5    Rajasthan       Jaipur  Locality_466              Villa    4
# ..   ...          ...          ...           ...                ...  ...
# 144  145       Kerala        Kochi  Locality_255          Apartment    2
# 156  157       Odisha  Bhubaneswar  Locality_491  Independent House    4
# 160  161       Kerala   Trivandrum  Locality_231          Apartment    5
# 167  168       Odisha      Cuttack  Locality_305          Apartment    3
# 172  173       Odisha  Bhubaneswar  Locality_350              Villa    1
#
#      Size_in_SqFt  Price_in_Lakhs  Price_per_SqFt  Year_Built  ...  \
# 0            4740          489.76            0.10        1990  ...
# 1            2364          195.52            0.08        2008  ...
# 2            3642          183.79            0.05        1997  ...
# 3            2741          300.29            0.11        1991  ...
# 4            4823          182.90            0.04        2002  ...
# ..            ...             ...             ...         ...  ...
# 144          2210           66.05            0.03        2014  ...
# 156          4745          377.58            0.08        1990  ...
# 160          3280          151.92            0.05        2014  ...
# 167          3967          427.00            0.11        2014  ...
# 172          1677           15.96            0.01        2009  ...
#
#     Nearby_Schools  Nearby_Hospitals  Public_Transport_Accessibility  \
# 0               10                 3                            High
# 1                8                 1                             Low
# 2                9                 8                             Low
# 3                5                 7                            High
# 4                4                 9                             Low
# ..             ...               ...                             ...
# 144              6                 5                          Medium
# 156              8                 7                          Medium
# 160              4                 8                             Low
# 167              7                 8                          Medium
# 172              8                 7                             Low
#
#      Parking_Space  Security                                 Amenities Facing  \
# 0               No        No  Playground, Gym, Garden, Pool, Clubhouse   West
# 1               No       Yes  Playground, Clubhouse, Pool, Gym, Garden  North
# 2              Yes        No          Clubhouse, Pool, Playground, Gym  South
# 3              Yes       Yes  Playground, Clubhouse, Gym, Pool, Garden  North
# 4               No       Yes  Playground, Garden, Gym, Pool, Clubhouse   East
# ..             ...       ...                                       ...    ...
# 144            Yes       Yes  Clubhouse, Gym, Garden, Pool, Playground  North
# 156             No       Yes                           Pool, Clubhouse   West
# 160             No        No  Playground, Garden, Gym, Clubhouse, Pool   East
# 167             No        No  Pool, Gym, Clubhouse, Garden, Playground   West
# 172             No       Yes                           Clubhouse, Pool   East
#
#     Owner_Type Availability_Status Age_of_Property
# 0        Owner       Ready_to_Move              35
# 1      Builder  Under_Construction              17
# 2       Broker       Ready_to_Move              28
# 3      Builder       Ready_to_Move              34
# 4      Builder       Ready_to_Move              23
# ..         ...                 ...             ...
# 144     Broker  Under_Construction              11
# 156    Builder       Ready_to_Move              35
# 160    Builder  Under_Construction              11
# 167     Broker  Under_Construction              11
# 172      Owner  Under_Construction              16
#
# [100 rows x 23 columns]

# %%
df.tail()
# Out:
#             ID       State       City      Locality      Property_Type  BHK  \
# 249995  249996     Gujarat  Ahmedabad  Locality_187  Independent House    5
# 249996  249997  Tamil Nadu    Chennai  Locality_348          Apartment    1
# 249997  249998   Telangana   Warangal  Locality_225              Villa    4
# 249998  249999      Odisha    Cuttack  Locality_138              Villa    1
# 249999  250000     Haryana    Gurgaon  Locality_268  Independent House    3
#
#         Size_in_SqFt  Price_in_Lakhs  Price_per_SqFt  Year_Built  ...  \
# 249995          1995          274.75            0.14        1995  ...
# 249996          2293           13.40            0.01        2013  ...
# 249997          2910          236.94            0.08        2003  ...
# 249998          1149          141.66            0.12        2007  ...
# 249999          4313          199.69            0.05        1990  ...
#
#        Nearby_Schools  Nearby_Hospitals  Public_Transport_Accessibility  \
# 249995              8                 6                             Low
# 249996              8                10                             Low
# 249997             10                 4                            High
# 249998              3                 7                             Low
# 249999             10                 6                          Medium
#
#         Parking_Space  Security                                 Amenities  \
# 249995             No        No  Playground, Garden, Gym, Clubhouse, Pool
# 249996             No        No                                Playground
# 249997            Yes       Yes                                Playground
# 249998            Yes       Yes                     Playground, Gym, Pool
# 249999             No        No                               Gym, Garden
#
#        Facing Owner_Type Availability_Status Age_of_Property
# 249995   East     Broker  Under_Construction              30
# 249996  South     Broker       Ready_to_Move              12
# 249997  South    Builder  Under_Construction              22
# 249998  South      Owner       Ready_to_Move              18
# 249999  South      Owner  Under_Construction              35
#
# [5 rows x 23 columns]
